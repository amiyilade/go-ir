# %% [markdown]
# # Go Code Understanding: Structural Analysis on Google Colab
# ## Setup and Installation
#
# Hello! This is a notebook to run the scripts I implemented for my FDL solo project. Hopefully, nothing is broken and should run smoothly in your environment :)
#
# I ran my own experiments on a Google Colab Pro account and it was a lengthy affair :/
#
# Enjoy!

# %%
# !nvidia-smi
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %%
# !pip install -r requirements.txt

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive
# !git clone https://github.com/amiyilade/go-ir.git
# %cd go-ir

# %%
# !python scripts/download_coir_go.py

# %%
# !python scripts/organise_coir_go_full.py

# %% [markdown]
# # Run from below if the folder is already existing

# %%
# Install packages, mount Google Drive, and cd to project directory (super quiet mode)
# !pip install -r requirements.txt -qqq

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/go-ir/

# %%
# Check if I made an update :D

# !git pull origin main

# %%
# !git log --oneline -5

# %%
# !python scripts/extract_go_constructs.py

# %%
# !python scripts/create_stratified_sample.py

# %%
# !python scripts/parse_asts.py

# %%
# !python scripts/extract_features.py --model unixcoder --task code-to-text

# %%
# !python scripts/extract_features.py --model unixcoder --task code-to-code

# %%
# !python scripts/extract_features.py --model codebert --task code-to-text

# %%
# !python scripts/extract_features.py --model codebert --task code-to-code

# %%
# !python scripts/rq1_prevalence.py

# %%
# !python scripts/rq2_attention.py --model unixcoder --task code-to-text

# %%
# !python scripts/rq2_attention.py --model unixcoder --task code-to-code

# %%
# !python scripts/rq2_attention.py --model codebert --task code-to-text

# %%
# !python scripts/rq2_attention.py --model codebert --task code-to-code

# %%
# !python scripts/rq3_probing.py --model unixcoder --task code-to-text

# %%
# !python scripts/rq3_probing.py --model unixcoder --task code-to-code

# %%
# !python scripts/rq3_probing.py --model codebert --task code-to-text

# %%
# !python scripts/rq3_probing.py --model codebert --task code-to-code

# %%
# !python scripts/rq4_constructs.py --model unixcoder --task code-to-text

# %%
# !python scripts/rq4_constructs.py --model unixcoder --task code-to-code

# %%
# !python scripts/rq4_constructs.py --model codebert --task code-to-text

# %%
# !python scripts/rq4_constructs.py --model codebert --task code-to-code

# %% [markdown]
# You might notice, if you choose to open up the script below, that it's got some failsafe for different dictionary keys being used. Midway through, I had changed some variable names and because re-running was expensive and there was no "data" mismatch (only variable names), I decided to just normalise that. Ideally, you shouldn't even need it because you will be running the latest script on all models and tasks.

# %%
# !python scripts/visualize.py
